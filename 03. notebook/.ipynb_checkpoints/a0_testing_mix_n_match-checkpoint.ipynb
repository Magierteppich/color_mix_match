# %%
import mix_n_match

# %%
mix_n_match.mix_n_match("../00_data/00_test_pic_full", n_init = 20, number_of_clusters = 4)
# Out:
# File ../00_data/00_test_pic_full/.DS_Store is not readable.
# File ../00_data/00_test_pic_full/.DS_Store is not readable.
# cluster 1
# cluster 2
# cluster 3
# cluster 4
