# %% [markdown]
# # Preperation for presentation:
#
# used to plot and find images to present

# %%
from img_preprocess import *
from img_feature import *

# %%
image_ready, valid_path = img_ready("../00_data/01_demo")
# Out:
# File ../00_data/01_demo/.DS_Store is not readable.

# %%
image_ready
# Out:
# [array([[[ 45,  53,  58],
#          [ 41,  48,  55],
#          [ 34,  37,  49],
#          ...,
#          [155, 165, 166],
#          [160, 170, 170],
#          [162, 172, 172]],
#
#         [[ 68,  75,  80],
#          [ 62,  69,  75],
#          [ 49,  53,  63],
#          ...,
#          [151, 163, 164],
#          [156, 167, 168],
#          [159, 169, 170]],
#
#         [[114, 119, 124],
#          [106, 112, 117],
#          [ 83,  88,  96],
#          ...,
#          [142, 157, 159],
#          [147, 161, 162],
#          [149, 162, 164]],
#
#         ...,
#         [[ 18,  35,  28],
#          [ 20,  37,  30],
#          [ 23,  41,  34],
#          ...,
#          [  7,  14,  14],
#          [  6,  12,  13],
#          [  6,  11,  13]],
#
#         [[ 17,  33,  26],
#          [ 18,  35,  28],
#          [ 22,  39,  32],
#          ...,
#          [  8,  15,  15],
#          [  7,  13,  14],
#          [  7,  13,  14]],
#
#         [[ 16,  32,  25],
# ...

# %%
feature, feature_list = img_get_feature(image_ready, valid_path)

# %%
import pandas as pd

df = pd.DataFrame(feature_list, columns=feature)
df
# Out:
#             H         S         V  colorfulness  contrast           R  \
# 0    101.3110  121.1799   74.5810     30.311604  0.138311   35.476240
# 1     75.3173  100.0280   48.1147     68.820056  0.142209    7.391226
# 2     55.9983   35.6670  123.3746     15.935494  0.218527   51.865166
# 3     65.0693   62.9328   92.3152     16.801208  0.278373   21.303076
# 4     19.2399   97.0071  162.1253     33.076773  0.173680  178.550860
# ..        ...       ...       ...           ...       ...         ...
# 96    66.3612  102.0506   61.0709     19.849695  0.126284   20.424490
# 97    65.6029    6.6372  195.5938      8.853710  0.067250  190.097510
# 98   102.2084   18.0587  227.1206     20.943584  0.196633  245.021513
# 99    45.5221   40.6834   71.7032     18.537239  0.202414   35.343566
# 100  105.8406  203.7645  212.8688    136.334182  0.143595   11.293656
#
#               G           B        kelvin
# 0     22.969361   21.340155   4684.065803
# ...

# %%
path_df = pd.DataFrame(valid_path)

# %%
df_new = pd.concat([path_df, df], axis = 1)

# %%
df_new = df_new.rename(columns = {0:"valid_path"})

# %%
df_new
# Out:
#                                             valid_path         H         S  \
# 0    ../00_data/01_demo/kelly-sikkema-4W1wo0U7Vuc-u...  101.3110  121.1799
# 1    ../00_data/01_demo/pietro-jeng-0Sd2qqU5soQ-uns...   75.3173  100.0280
# 2    ../00_data/01_demo/photo-1505069446780-4ef442b...   55.9983   35.6670
# 3    ../00_data/01_demo/simone-mascellari-7QK_VsynT...   65.0693   62.9328
# 4    ../00_data/01_demo/dusan-smetana-ZXuDkw7Be7E-u...   19.2399   97.0071
# ..                                                 ...       ...       ...
# 96   ../00_data/01_demo/maksym-ivashchenko-7P9cPzWK...   66.3612  102.0506
# 97   ../00_data/01_demo/photo-1533090161767-e6ffed9...   65.6029    6.6372
# 98   ../00_data/01_demo/photo-1533038590840-1cde6e6...  102.2084   18.0587
# 99   ../00_data/01_demo/smit-patel-dGMcpbzcq1I-unsp...   45.5221   40.6834
# 100  ../00_data/01_demo/photo-1524293568345-75d62c3...  105.8406  203.7645
#
# ...

# %%
pd.to_pickle(df_new, "feature_list")

# %%
df_new.corr()
# Out:
#                      H         S         V  colorfulness  contrast         R  \
# H             1.000000  0.038589 -0.005607      0.144058 -0.195154 -0.160304
# S             0.038589  1.000000 -0.139172      0.776284 -0.193592 -0.266109
# V            -0.005607 -0.139172  1.000000      0.232548  0.026793  0.816258
# colorfulness  0.144058  0.776284  0.232548      1.000000  0.009996  0.062262
# contrast     -0.195154 -0.193592  0.026793      0.009996  1.000000  0.032411
# R            -0.160304 -0.266109  0.816258      0.062262  0.032411  1.000000
# G            -0.023364 -0.207593  0.901236      0.179089  0.012312  0.882224
# B             0.196590 -0.390702  0.751248      0.023298  0.030611  0.670598
# kelvin        0.303228  0.131576  0.151158      0.180256 -0.071430 -0.215226
#
#                      G         B    kelvin
# H            -0.023364  0.196590  0.303228
# S            -0.207593 -0.390702  0.131576
# V             0.901236  0.751248  0.151158
# ...

# %%
# image with maximum colorfulness
df_new.loc[df_new["colorfulness"] == df_new["colorfulness"].max()]
# Out:
#                                             valid_path         H         S  \
# 100  ../00_data/01_demo/photo-1524293568345-75d62c3...  105.8406  203.7645
#
#             V  colorfulness  contrast          R           G           B  \
# 100  212.8688    136.334182  0.143595  11.293656  197.732163  228.707107
#
#            kelvin
# 100  14617.521508

# %%
# image with min colorfulness
df_new.loc[df_new["colorfulness"] == df_new["colorfulness"].min()]
# Out:
#                                            valid_path      H       S  \
# 49  ../00_data/01_demo/photo-1487700160041-babef9c...  6.421  6.7647
#
#            V  colorfulness  contrast           R           G           B  \
# 49  225.1142      8.620544  0.141684  233.846398  233.891956  233.843539
#
#          kelvin
# 49  6445.342604

# %%
df_new.sort_values(by=["contrast"])
# Out:
#                                            valid_path        H         S  \
# 71  ../00_data/01_demo/giorgio-trovato-czw_E5nK28Y...  97.6606   24.7859
# 81  ../00_data/01_demo/rodion-kutsaev-IJ25m7fXqtk-...  24.3176  252.6567
# 97  ../00_data/01_demo/photo-1533090161767-e6ffed9...  65.6029    6.6372
# 36  ../00_data/01_demo/photo-1516048015710-7a3b4c8...  19.3089   89.4501
# 89  ../00_data/01_demo/david-kovalenko-G85VuTpw6jg...  74.8503  109.8715
# ..                                                ...      ...       ...
# 3   ../00_data/01_demo/simone-mascellari-7QK_VsynT...  65.0693   62.9328
# 56  ../00_data/01_demo/adam-thomas-f_UBYuOuMJw-uns...  22.7343   89.1611
# 54  ../00_data/01_demo/john-cameron-dus1vufqJPc-un...  70.6253  105.1596
# 34  ../00_data/01_demo/swabdesign-0HgPViWeIb8-unsp...  37.4229   30.5184
# 45  ../00_data/01_demo/photo-1525498128493-380d199...  38.8690   82.2061
#
#            V  colorfulness  contrast           R           G           B  \
# ...

# %%
# min contrast
df_new.loc[df_new["contrast"] == df_new["contrast"].max()]
# Out:
#                                            valid_path       H        S  \
# 45  ../00_data/01_demo/photo-1525498128493-380d199...  38.869  82.2061
#
#            V  colorfulness  contrast          R          G          B  \
# 45  142.1164      28.44851  0.345208  32.321333  54.185272  21.529906
#
#         kelvin
# 45  5843.22426

# %%
# max contrast
df_new.loc[df_new["contrast"] == df_new["contrast"].min()]
# Out:
#                                            valid_path        H        S  \
# 71  ../00_data/01_demo/giorgio-trovato-czw_E5nK28Y...  97.6606  24.7859
#
#            V  colorfulness  contrast           R           G           B  \
# 71  213.7453     18.665616  0.051701  205.355722  211.831451  216.529108
#
#          kelvin
# 71  7462.750824

# %%
# max kelvin
df_new.loc[df_new["kelvin"] == df_new["kelvin"].max()]
# Out:
#                                            valid_path       H       S  \
# 84  ../00_data/01_demo/jason-leung-Xaanw0s0pMk-uns...  94.464  233.81
#
#            V  colorfulness  contrast         R           G           B  \
# 84  160.0967     89.501932  0.117634  6.908894  102.828429  123.544894
#
#           kelvin
# 84  24471.164783

# %%
# min kelvin
df_new.loc[df_new["kelvin"] == df_new["kelvin"].min()]
# Out:
#                                            valid_path         H         S  \
# 95  ../00_data/01_demo/michael-dziedzic-becs5wiAnS...  148.4999  196.9065
#
#           V  colorfulness  contrast          R         G        B      kelvin
# 95  62.0483     74.680072  0.096813  13.002767  3.740476  7.32888  343.957466

# %%
pd.options.display.float_format = '{:20,.2f}'.format


df_new.sort_values(by=["kelvin"])
# Out:
#                                             valid_path                    H  \
# 95   ../00_data/01_demo/michael-dziedzic-becs5wiAnS...               148.50
# 29   ../00_data/01_demo/kelly-sikkema-jumNGn7kBl0-u...               138.32
# 20   ../00_data/01_demo/nathan-de-fortunato-EGW2Iaq...                85.27
# 1    ../00_data/01_demo/pietro-jeng-0Sd2qqU5soQ-uns...                75.32
# 43   ../00_data/01_demo/carson-arias-7Z03R1wOdmI-un...                18.58
# ..                                                 ...                  ...
# 48   ../00_data/01_demo/max-bender-VmX3vmBecFE-unsp...               116.02
# 100  ../00_data/01_demo/photo-1524293568345-75d62c3...               105.84
# 52   ../00_data/01_demo/photo-1483683804023-6ccdb62...                89.22
# 91   ../00_data/01_demo/photo-1507608616759-54f48f0...                92.39
# 84   ../00_data/01_demo/jason-leung-Xaanw0s0pMk-uns...                94.46
#
# ...

# %%
df_new.sort_values(by=["S"])
# Out:
#                                             valid_path                    H  \
# 97   ../00_data/01_demo/photo-1533090161767-e6ffed9...                65.60
# 49   ../00_data/01_demo/photo-1487700160041-babef9c...                 6.42
# 61   ../00_data/01_demo/hipster-mum-XookgCxFw6Q-uns...               106.70
# 69   ../00_data/01_demo/josephine-menge-h7VBJRBcieM...                33.78
# 31   ../00_data/01_demo/ryoji-iwata-n31JPLu8_Pw-uns...               153.25
# ..                                                 ...                  ...
# 100  ../00_data/01_demo/photo-1524293568345-75d62c3...               105.84
# 24   ../00_data/01_demo/sahil-sorathiya-YW3F-C5e8SE...                52.06
# 43   ../00_data/01_demo/carson-arias-7Z03R1wOdmI-un...                18.58
# 84   ../00_data/01_demo/jason-leung-Xaanw0s0pMk-uns...                94.46
# 81   ../00_data/01_demo/rodion-kutsaev-IJ25m7fXqtk-...                24.32
#
# ...

# %%
# max hue
df_new.loc[df_new["H"] == df_new["H"].max()]
# Out:
#                                            valid_path                    H  \
# 23  ../00_data/01_demo/ian-dooley-k8OCHhEymME-unsp...               165.62
#
#                       S                    V         colorfulness  \
# 23                38.42               238.33                25.12
#
#                contrast                    R                    G  \
# 23                 0.09               242.88               212.12
#
#                       B               kelvin
# 23               219.35             5,460.33

# %%
df_new.loc[df_new["H"] == df_new["H"].min()]
# Out:
#                                            valid_path                    H  \
# 49  ../00_data/01_demo/photo-1487700160041-babef9c...                 6.42
#
#                       S                    V         colorfulness  \
# 49                 6.76               225.11                 8.62
#
#                contrast                    R                    G  \
# 49                 0.14               233.85               233.89
#
#                       B               kelvin
# 49               233.84             6,445.34

# %%
# Hue max / min does not really make sense, as it is another way to express the color. 
# https://www.lifewire.com/what-is-hsv-in-design-1078068

# %%
# max saturation:

df_new.loc[df_new["S"] == df_new["S"].max()]
# Out:
#                                            valid_path                    H  \
# 81  ../00_data/01_demo/rodion-kutsaev-IJ25m7fXqtk-...                24.32
#
#                       S                    V         colorfulness  \
# 81               252.66               245.15                89.00
#
#                contrast                    R                    G  \
# 81                 0.06               251.77               205.49
#
#                       B               kelvin
# 81                 0.87             3,056.17

# %%
df_new.sort_values(by=["V"])
# Out:
#                                            valid_path                    H  \
# 85  ../00_data/01_demo/omid-armin-2GHCdtW45Uw-unsp...                78.91
# 1   ../00_data/01_demo/pietro-jeng-0Sd2qqU5soQ-uns...                75.32
# 80  ../00_data/01_demo/patrick-sheehan-yP4QJaw9Mog...               158.01
# 73  ../00_data/01_demo/jc-gellidon-Khqmo4T-rs0-uns...                67.55
# 96  ../00_data/01_demo/maksym-ivashchenko-7P9cPzWK...                66.36
# ..                                                ...                  ...
# 65  ../00_data/01_demo/photo-1524055988636-436cfa4...                22.38
# 61  ../00_data/01_demo/hipster-mum-XookgCxFw6Q-uns...               106.70
# 23  ../00_data/01_demo/ian-dooley-k8OCHhEymME-unsp...               165.62
# 36  ../00_data/01_demo/photo-1516048015710-7a3b4c8...                19.31
# 81  ../00_data/01_demo/rodion-kutsaev-IJ25m7fXqtk-...                24.32
#
#                       S                    V         colorfulness  \
# ...

# %%
df_new.loc[df_new["S"] == df_new["S"].min()]
# Out:
#                                            valid_path                    H  \
# 97  ../00_data/01_demo/photo-1533090161767-e6ffed9...                65.60
#
#                       S                    V         colorfulness  \
# 97                 6.64               195.59                 8.85
#
#                contrast                    R                    G  \
# 97                 0.07               190.10               190.02
#
#                       B               kelvin
# 97               190.04             6,500.96

# %%
# brightness
df_new.loc[df_new["V"] == df_new["V"].max()]
# Out:
#                                            valid_path                    H  \
# 81  ../00_data/01_demo/rodion-kutsaev-IJ25m7fXqtk-...                24.32
#
#                       S                    V         colorfulness  \
# 81               252.66               245.15                89.00
#
#                contrast                    R                    G  \
# 81                 0.06               251.77               205.49
#
#                       B               kelvin
# 81                 0.87             3,056.17

# %%
df_new.loc[df_new["V"] == df_new["V"].min()]
# Out:
#                                            valid_path                    H  \
# 85  ../00_data/01_demo/omid-armin-2GHCdtW45Uw-unsp...                78.91
#
#                       S                    V         colorfulness  \
# 85                81.61                39.58                18.02
#
#                contrast                    R                    G  \
# 85                 0.12                11.49                11.63
#
#                       B               kelvin
# 85                14.93             5,137.72

# %%
img_ready_pr, valid_path = img_ready("../00_data/02_presentation")
# Out:
# File ../00_data/02_presentation/.DS_Store is not readable.

# %%
from dominant_color_only import *

# %%
valid_path
# Out:
# [['../00_data/02_presentation/ian-dooley-k8OCHhEymME-unsplash.jpg'],
#  ['../00_data/02_presentation/linnea-sandbakk-HQqIOc8oYro-unsplash.jpg'],
#  ['../00_data/02_presentation/vicko-mozara-m82uh_vamhg-unsplash.jpg'],
#  ['../00_data/02_presentation/efe-kurnaz-RnCPiXixooY-unsplash.jpg'],
#  ['../00_data/02_presentation/angello-pro-rnRz0dmn1SI-unsplash.jpg']]

# %%
img_dominant_color(img_ready_pr)
# Out:
# [[(0.95209862144701674, 0.83072628134033377, 0.85899937961939721),
#   (0.53615520282186213, 0.3038454888128016, 0.36647646713005605),
#   (0.86085331493300687, 0.60385256741992022, 0.64353784524563606)],
#  [(0.75742391511262197, 0.63290252360972699, 0.46132106705071535),
#   (0.15881604609714983, 0.16362329618185978, 0.13091107795585799),
#   (0.42558189869993851, 0.38708331553389241, 0.26155125521523392)],
#  [(0.035175785125594577, 0.57352093367248891, 0.49538250626833613),
#   (0.76695820721481545, 0.74425903924958314, 0.73985309540433419),
#   (0.41052704882098257, 0.68249791481690736, 0.64858832708965852)],
#  [(0.33515101732951091, 0.49078966061467716, 0.60006664238609875),
#   (0.899701030707453, 0.34413243249016351, 0.53797764532730752),
#   (0.3368033213665092, 0.12937125417383274, 0.40495968207928379)],
#  [(0.61224627152939315, 0.63530305852549696, 0.53432067950673046),
#   (0.056609186981254188, 0.48091420469689217, 0.52162277194701712),
# ...

# %%
from img_knn import *

# %%
image_ready, valid_path = img_ready("../00_data/01_demo/")
# Out:
# File ../00_data/01_demo//.DS_Store is not readable.

# %%
target_image = "gary-bendig-6GMq7AGxNbE-unsplash.jpg"

# %%
target_index = find_target_image(valid_path, target_image)

# %%
features, feature_list = img_get_feature(image_ready, valid_path)

# %%
img_ready_gray = color_to_gray(image_ready)

# %%
list_img_mse = get_img_mse(img_ready_gray, target_index)

# %%
from skimage.metrics import structural_similarity as ssim

# %%
list_img_ssim = get_img_ssim(img_ready_gray, target_index)

# %%
feature_list_knn, features_knn = get_feature_list_knn(valid_path, features, feature_list, list_img_mse, list_img_ssim)

# %%
knn = pd.DataFrame(feature_list_knn, columns=features_knn)

# %%
knn
# Out:
#                        H                    S                    V  \
# 0                 101.31               121.18                74.58
# 1                  75.32               100.03                48.11
# 2                  56.00                35.67               123.37
# 3                  65.07                62.93                92.32
# 4                  19.24                97.01               162.13
# ..                   ...                  ...                  ...
# 96                 66.36               102.05                61.07
# 97                 65.60                 6.64               195.59
# 98                102.21                18.06               227.12
# 99                 45.52                40.68                71.70
# 100               105.84               203.76               212.87
#
#             colorfulness             contrast                    R  \
# 0                  30.31                 0.14                35.33
# ...

# %%
knn_path = pd.DataFrame(valid_path, columns=["valid_path"])

# %%
knn_new = pd.concat([knn_path, knn], axis=1)

# %%
knn_new
# Out:
#                                             valid_path                    H  \
# 0    ../00_data/01_demo//kelly-sikkema-4W1wo0U7Vuc-...               101.31
# 1    ../00_data/01_demo//pietro-jeng-0Sd2qqU5soQ-un...                75.32
# 2    ../00_data/01_demo//photo-1505069446780-4ef442...                56.00
# 3    ../00_data/01_demo//simone-mascellari-7QK_Vsyn...                65.07
# 4    ../00_data/01_demo//dusan-smetana-ZXuDkw7Be7E-...                19.24
# ..                                                 ...                  ...
# 96   ../00_data/01_demo//maksym-ivashchenko-7P9cPzW...                66.36
# 97   ../00_data/01_demo//photo-1533090161767-e6ffed...                65.60
# 98   ../00_data/01_demo//photo-1533038590840-1cde6e...               102.21
# 99   ../00_data/01_demo//smit-patel-dGMcpbzcq1I-uns...                45.52
# 100  ../00_data/01_demo//photo-1524293568345-75d62c...               105.84
#
# ...

# %%
knn_new.loc[knn_new["SSIM"] == knn_new["SSIM"].min()]
# Out:
#                                            valid_path                    H  \
# 31  ../00_data/01_demo//ryoji-iwata-n31JPLu8_Pw-un...               153.25
#
#                       S                    V         colorfulness  \
# 31                16.20               170.87                 9.84
#
#                contrast                    R                    G  \
# 31                 0.25                99.60                90.11
#
#                       B               kelvin                  MSE  \
# 31                98.06             6,476.34             6,856.88
#
#                    SSIM
# 31                 0.03
