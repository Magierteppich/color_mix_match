# %% [markdown]
# # img_get_feature function
#
# - The function img_get_feature takes in the path_to_library and returns a list of dictionaries.
# - Each dictionary contains the key features of 1 image.

# %%
import image_all_features as iaf
import pandas as pd
import image_preprocessing as ip

# %%
valid_path, features, feature_list = iaf.img_get_feature("../00_data/00_test_pic_full", height = 220, width = 220, k=4)
# Out:
# File ../00_data/00_test_pic_full/.DS_Store is not readable.
# File ../00_data/00_test_pic_full/.DS_Store is not readable.

# %%
feature_list
# Out:
# [[53.945599999999999,
#   184.01929999999999,
#   139.62620000000001,
#   104.00922051944494,
#   27.959908221473604,
#   51.891254343483887,
#   119.73929427886134,
#   109.72862526307148,
#   3817.6381579750705],
#  [33.395400000000002,
#   105.133,
#   139.9589,
#   43.10774883255165,
#   60.060202618251608,
#   108.86169045004024,
#   110.92995661492479,
#   70.558360775703107,
#   4555.7261309532714],
#  [55.740099999999998,
#   123.43989999999999,
#   38.244199999999999,
#   17.558230436247342,
#   44.015709225084471,
#   6.9561746702779814,
#   13.601217896116093,
#   5.225089922392133,
#   5812.2301644895924],
#  [76.734499999999997,
#   141.2243,
#   121.0788,
#   64.645675631334356,
#   61.43287535768723,
#   42.890298547768168,
#   41.400259137270751,
#   16.978837121433536,
#   3726.0424516952139],
#  [80.546599999999998,
#   105.49169999999999,
#   84.821700000000007,
#   33.927606953287487,
#   71.687542252364054,
#   21.281072355981287,
#   22.151800126297772,
# ...
