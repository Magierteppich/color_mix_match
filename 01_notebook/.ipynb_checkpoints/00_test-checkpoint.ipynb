# %%
import image_neighbors

# %%
import mix_n_match

# %%
mix_n_match.mix_n_match("../00_data/01_demo")
# Out:
# File ../00_data/01_demo/.DS_Store is not readable.
# File ../00_data/01_demo/.DS_Store is not readable.
# cluster 1
# cluster 2
# cluster 3
# cluster 4
# cluster 5

# %%
image_neighbors.mix_n_match_neighbors("../00_data/01_demo", "linnea-sandbakk-HQqIOc8oYro-unsplash.jpg", 5)
# Out:
# File ../00_data/01_demo/.DS_Store is not readable.
# File ../00_data/01_demo/.DS_Store is not readable.
# File ../00_data/01_demo/.DS_Store is not readable.
