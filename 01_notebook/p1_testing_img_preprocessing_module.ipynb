# %% [markdown]
# # p1_testing_img_preprocessing_module

# %%
import image_preprocessing as ip

# %%
list = ip.image_ready("../00_data/00_test_pic")
# Out:
# File ../00_data/00_test_pic/.DS_Store is not readable.

# %%
new_list = ip.image_ready("../00_data/00_test_pic", height = 400, width = 400)
new_list
# Out:
# File ../00_data/00_test_pic/.DS_Store is not readable.
# [array([[[ 39,  97,  43],
#          [ 39,  97,  43],
#          [ 39,  97,  43],
#          ...,
#          [ 27,  61,  26],
#          [ 40,  71,  39],
#          [ 48,  78,  47]],
#
#         [[ 39,  97,  43],
#          [ 39,  97,  43],
#          [ 39,  97,  43],
#          ...,
#          [ 27,  61,  26],
#          [ 40,  71,  39],
#          [ 48,  78,  47]],
#
#         [[ 39,  97,  43],
#          [ 39,  97,  43],
#          [ 39,  97,  43],
#          ...,
#          [ 27,  61,  26],
#          [ 40,  71,  39],
#          [ 48,  78,  47]],
#
#         ...,
#
#         [[ 15, 110,  36],
#          [ 15, 110,  36],
#          [ 15, 111,  37],
#          ...,
#          [ 30, 131,  57],
#          [ 43, 139,  69],
#          [ 51, 145,  77]],
#
#         [[ 15, 110,  35],
#          [ 15, 110,  35],
#          [ 14, 110,  36],
#          ...,
#          [ 30, 132,  59],
#          [ 43, 140,  71],
# ...
