# %%
from img_preprocess import *
from img_feature import *

# %%
image_ready, valid_path = img_ready("../00_data/01_demo/")
# Out:
# File ../00_data/01_demo//.DS_Store is not readable.

# %%
valid_path
# Out:
# [['../00_data/01_demo//kelly-sikkema-4W1wo0U7Vuc-unsplash.jpg'],
#  ['../00_data/01_demo//pietro-jeng-0Sd2qqU5soQ-unsplash.jpg'],
#  ['../00_data/01_demo//photo-1505069446780-4ef442b5207f.jpeg'],
#  ['../00_data/01_demo//simone-mascellari-7QK_VsynTRA-unsplash.jpg'],
#  ['../00_data/01_demo//dusan-smetana-ZXuDkw7Be7E-unsplash.jpg'],
#  ['../00_data/01_demo//kristopher-roller-PC_lbSSxCZE-unsplash.jpg'],
#  ['../00_data/01_demo//boris-smokrovic-DPXytK8Z59Y-unsplash.jpg'],
#  ['../00_data/01_demo//photo-1518012312832-96aea3c91144.jpeg'],
#  ['../00_data/01_demo//photo-1494438639946-1ebd1d20bf85.jpeg'],
#  ['../00_data/01_demo//jonathan-borba-aaLyHWE9WA8-unsplash.jpg'],
#  ['../00_data/01_demo//angello-pro-KxqEoimZPsM-unsplash.jpg'],
#  ['../00_data/01_demo//patrick-keller-lEOKaF1WvVU-unsplash.jpg'],
#  ['../00_data/01_demo//denys-nevozhai-7nrsVjvALnA-unsplash.jpg'],
#  ['../00_data/01_demo//klara-kulikova-LeMpBbkdxFs-unsplash.jpg'],
# ...

# %%
img_contrast(image_ready)
# Out:
# [[0.13831119498128472],
#  [0.14220897299161933],
#  [0.21852691981303082],
#  [0.27837327620035834],
#  [0.17368029355295905],
#  [0.13433391912711276],
#  [0.14307353189250219],
#  [0.17240181673736429],
#  [0.12550354674533815],
#  [0.21407378628920509],
#  [0.14895107353408654],
#  [0.19169583340132121],
#  [0.14842144516711056],
#  [0.10660630007819961],
#  [0.17389078550709638],
#  [0.1367429821906867],
#  [0.11724449704705746],
#  [0.15377722620596546],
#  [0.18049013760206462],
#  [0.19386076798825305],
#  [0.12114938593436933],
#  [0.1732487659196712],
#  [0.15736788014992534],
#  [0.093714827271196718],
#  [0.14587101913697173],
#  [0.17549544149631505],
#  [0.12825153196381114],
#  [0.23935174916725854],
#  [0.13733746055905571],
#  [0.20625959849828923],
#  [0.25269563447462667],
#  [0.15430469102852068],
#  [0.2017351320077542],
#  [0.28164095545419554],
#  [0.26440992209757525],
#  [0.088636247140571764],
#  [0.19879195868528074],
#  [0.23464857700847358],
# ...

# %%
from mix_n_match_knn import *

# %%
mix_n_match_knn("../00_data/01_demo/", "angello-pro-KxqEoimZPsM-unsplash.jpg", 4)
# Out:
# File ../00_data/01_demo//.DS_Store is not readable.
# Fot the image chosen ../00_data/01_demo//angello-pro-KxqEoimZPsM-unsplash.jpg, the following 4 images may fit well:
# -----------------------------------------------------
# ../00_data/01_demo//angello-pro-rnRz0dmn1SI-unsplash.jpg
# ../00_data/01_demo//vicko-mozara-m82uh_vamhg-unsplash.jpg
# ../00_data/01_demo//photo-1507608616759-54f48f0af0ee.jpeg
# ../00_data/01_demo//photo-1483683804023-6ccdb62f86ef.jpeg

# %%
# --> contrast normalized to 1, and it works.

# %%
image_ready, valid_path = img_ready("../00_data/01_demo/")
# Out:
# File ../00_data/01_demo//.DS_Store is not readable.

# %%
img_colorfulness(image_ready)
# Out:
# [[30.311604310112568],
#  [68.820056282358266],
#  [15.935494463369404],
#  [16.80120757839574],
#  [33.076773344506094],
#  [31.474749906340975],
#  [58.16351115200959],
#  [16.163424587159046],
#  [10.084944931463427],
#  [29.260986539423079],
#  [88.76312601482087],
#  [47.783468842546071],
#  [28.304484129403875],
#  [26.159487727150108],
#  [33.931640874918806],
#  [44.013875095408928],
#  [22.167531701346714],
#  [43.945716982356956],
#  [26.642826995461363],
#  [62.25498290281606],
#  [46.990271603392074],
#  [11.995614760173584],
#  [23.089741359199351],
#  [25.124642853321014],
#  [59.775760394287047],
#  [51.901506361571037],
#  [43.600288916284065],
#  [82.827948730865998],
#  [32.108730396574721],
#  [57.622233154253358],
#  [26.24176316619392],
#  [9.8433594939994542],
#  [29.418260725534438],
#  [44.22062210258288],
#  [10.201222859590491],
#  [110.24754418610945],
#  [43.187685783870492],
#  [45.471713392764315],
#  [57.741649073832491],
#  [43.790294474881122],
# ...
