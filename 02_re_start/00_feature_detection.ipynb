# %%
# source: https://www.analyticsvidhya.com/blog/2019/08/3-techniques-extract-features-from-image-data-machine-learning-python/

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from skimage.io import imread, imshow

# %%
image = imread("tree.jpg", as_gray=True)

# %%
imshow(image)

# %%
image.shape
# Out:
# (667, 1000)

# %%
image_2 = imread("tree.jpg")

# %%
image_2.shape
# Out:
# (667, 1000, 3)

# %%
feature_matrix_2 = np.zeros((667, 1000))

# %%
from skimage.filters import prewitt_h, prewitt_v

# %%
edges_prewitt_horizontal = prewitt_h (image)
edges_prewitt_vertical = prewitt_v (image)

# %%
imshow(edges_prewitt_vertical, cmap="gray")

# %%
image
# Out:
# array([[0.27988118, 0.27988118, 0.28548431, ..., 0.32477529, 0.32477529,
#         0.32477529],
#        [0.28772431, 0.29164588, 0.29023922, ..., 0.32869686, 0.32869686,
#         0.32477529],
#        [0.28296941, 0.28772431, 0.28548431, ..., 0.32477529, 0.32002039,
#         0.32477529],
#        ...,
#        [0.36353529, 0.33560902, 0.29785255, ..., 0.48353961, 0.41279647,
#         0.37750235],
#        [0.39098627, 0.36809059, 0.30961725, ..., 0.48297412, 0.37414627,
#         0.39094157],
#        [0.38847137, 0.38599412, 0.31744549, ..., 0.49081725, 0.39432745,
#         0.43407882]])

# %%
import cv2

# %%
img = cv2.imread("tree.jpg", 1)
cv2.imshow("original", img)
cv2.waitKey(2000)
# Out:
# -1

# %%
img
# Out:
# array([[[117,  85,  10],
#         [117,  85,  10],
#         [121,  86,  12],
#         ...,
#         [135,  98,  14],
#         [135,  98,  14],
#         [135,  98,  14]],
#
#        [[119,  87,  12],
#         [120,  88,  13],
#         [122,  87,  14],
#         ...,
#         [136,  99,  15],
#         [136,  99,  15],
#         [135,  98,  14]],
#
#        [[118,  86,  10],
#         [119,  87,  12],
#         [121,  86,  12],
#         ...,
#         [135,  98,  14],
#         [134,  97,  12],
#         [135,  98,  14]],
#
#        ...,
#
#        [[ 53,  88, 122],
#         [ 51,  83, 106],
#         [ 44,  75,  90],
#         ...,
#         [ 71, 115, 169],
#         [ 61, 100, 138],
#         [ 52,  91, 129]],
#
#        [[ 60,  95, 129],
#         [ 53,  92, 114],
#         [ 47,  78,  93],
#         ...,
#         [ 69, 115, 169],
#         [ 53,  90, 128],
#         [ 51,  95, 132]],
#
#        [[ 57,  95, 127],
#         [ 56,  96, 121],
#         [ 46,  80,  96],
# ...

# %%
r = 100 / img.shape[1]
dim = (100, int(image.shape[0] * r))

# %%
dim
# Out:
# (100, 66)

# %%
resized = cv2.resize(image, (32, 32), interpolation = cv2.INTER_AREA)
cv2.imshow("resized", resized)
cv2.waitKey(2000)
# Out:
# -1

# %%
resized.shape
# Out:
# (32, 32)

# %%
cv2.imwrite("tree_resized.jpg", resized)
# Out:
# True
